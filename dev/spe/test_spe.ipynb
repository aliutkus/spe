# %%
# %load_ext autoreload
# %autoreload 2

import torch
import spe
import numpy as np
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
v = np.zeros((100, 1))
v[::10] = 1
plt.subplot(211)
plt.plot(v[:100])
R = np.abs(np.fft.rfft(v))
plt.subplot(212)
plt.plot(R)

# %%
n=1000
test = model.spe(shape=(n,), n_draws=64, lengthscale=0.3)
import matplotlib.pylab as plt
plt.figure(figsize=(20,10))
plt.subplot(121)
plt.plot(test[0])
print(test.shape)
import numpy as np
xcorr = np.zeros((n))
for lag in range(n):
    #for lag2 in range(n):
        xcorr[lag] = torch.dot(test[:, n//2], test[:,lag])
plt.subplot(122)
plt.plot(torch.tensor(xcorr))
plt.grid(True)
#test.view(64,-1).norm(dim=1)
# Out:
# torch.Size([64, 1000])

# %%
test
# Out:
# tensor([[-0.0178, -0.0170, -0.0161,  ..., -0.1410, -0.1408, -0.1405],
#         [-0.1519, -0.1526, -0.1532,  ..., -0.0382, -0.0386, -0.0389],
#         [ 0.0826,  0.0830,  0.0834,  ...,  0.0871,  0.0876,  0.0881],
#         ...,
#         [ 0.0454,  0.0455,  0.0457,  ...,  0.0773,  0.0760,  0.0747],
#         [ 0.1203,  0.1212,  0.1221,  ...,  0.0723,  0.0721,  0.0719],
#         [-0.0729, -0.0731, -0.0732,  ..., -0.0821, -0.0820, -0.0818]])
